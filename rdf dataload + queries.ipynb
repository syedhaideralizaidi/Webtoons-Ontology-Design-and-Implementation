# %%
# !pip install rdflib
import numpy as np
import pandas as pd
from rdflib import Graph
from rdflib import URIRef, Literal
from rdflib import Namespace
from rdflib.namespace import OWL, RDF, RDFS, XSD
# Out:
# Requirement already satisfied: rdflib in c:\users\zzakn\anaconda3\lib\site-packages (6.2.0)
# Requirement already satisfied: pyparsing in c:\users\zzakn\anaconda3\lib\site-packages (from rdflib) (3.0.4)
# Requirement already satisfied: setuptools in c:\users\zzakn\anaconda3\lib\site-packages (from rdflib) (59.5.0)
# Requirement already satisfied: isodate in c:\users\zzakn\anaconda3\lib\site-packages (from rdflib) (0.6.1)
# Requirement already satisfied: six in c:\users\zzakn\anaconda3\lib\site-packages (from isodate->rdflib) (1.16.0)
# Requirement already satisfied: rdflib in c:\users\zzakn\anaconda3\lib\site-packages (6.2.0)
# Requirement already satisfied: pyparsing in c:\users\zzakn\anaconda3\lib\site-packages (from rdflib) (3.0.4)
# Requirement already satisfied: setuptools in c:\users\zzakn\anaconda3\lib\site-packages (from rdflib) (59.5.0)
# Requirement already satisfied: isodate in c:\users\zzakn\anaconda3\lib\site-packages (from rdflib) (0.6.1)
# Requirement already satisfied: six in c:\users\zzakn\anaconda3\lib\site-packages (from isodate->rdflib) (1.16.0)

# %%
dataframe = pd.read_csv('Webtoon Dataset.csv')
dataframe.at[319,'Writer']= "mame"
dataframe
# Out:
#       id                      Name                      Writer     Likes  \
# 0      0                Let's Play  Leeanne M. Krecic (Mongie)     30.6M
# 1      1               True Beauty                     Yaongyi     39.9M
# 2      2       Midnight Poppy Land                    Lilydusk     10.4M
# 3      3               Age Matters                 Enjelicious     25.9M
# 4      4              Unholy Blood    Lina Im / Jeonghyeon Kim      9.9M
# ..   ...                       ...                         ...       ...
# 562  563                 Wolfsbane     Ryan Cady / Morgan Beem  1,44,341
# 563  564       Third Shift Society           Meredith Moriarty  8,66,428
# 564  565                Adamsville              Michael Regina  1,84,981
# 565  566               WEBTOON Now      LOZOLZ / Wyatt the Cat      1.9M
# 566  567  Staying Healthy Together             Various Artists      1.5M
#
#             Genre Rating Subscribers  \
# 0         Romance   9.62        4.2M
# 1         Romance    9.6        6.4M
# 2         Romance   9.81        2.1M
# 3         Romance   9.79        3.5M
# 4    Supernatural   9.85        1.5M
# ..            ...    ...         ...
# 562        Horror   9.68       66.3K
# 563  Supernatural   9.78      376.9K
# 564       Mystery   9.32       60.4K
# 565   Informative   9.25      459.2K
# 566   Informative   9.76      204.6K
#
#                                                Summary              Update  \
# 0    She's young, single and about to achieve her d...    UP EVERY TUESDAY
# 1    After binge-watching beauty videos online, a s...  UP EVERY WEDNESDAY
# 2    After making a grisly discovery in the country...   UP EVERY SATURDAY
# 3    She's a hopeless romantic who's turning 30's  ...  UP EVERY WEDNESDAY
# 4    When vampires destroy her chance to have the n...   UP EVERY THURSDAY
# ..                                                 ...                 ...
# 562  Following in her father's legacy, Quinn's enti...           COMPLETED
# 563  Life's funny. One minute you're jobless, deep ...     UP EVERY FRIDAY
# 564  "Adamsville" is an all ages series about two m...           COMPLETED
# 565                        Get your WEBTOON news here!     UP EVERY MONDAY
# 566  A series of tips for staying safe during the C...           COMPLETED
#
#                                           Reading Link Unnamed: 10
# 0    https://www.webtoons.com/en/romance/letsplay/l...         NaN
# 1    https://www.webtoons.com/en/romance/truebeauty...         NaN
# 2    https://www.webtoons.com/en/romance/midnight-p...         NaN
# 3    https://www.webtoons.com/en/romance/age-matter...         NaN
# 4    https://www.webtoons.com/en/supernatural/unhol...         NaN
# ..                                                 ...         ...
# 562  https://www.webtoons.com/en/horror/wolfsbane/l...         NaN
# 563  https://www.webtoons.com/en/supernatural/third...         NaN
# 564  https://www.webtoons.com/en/mystery/adamsville...         NaN
# 565  https://www.webtoons.com/en/tiptoon/webtoon-no...         NaN
# 566  https://www.webtoons.com/en/tiptoon/staying-he...         NaN
#
# [567 rows x 11 columns]
#       id                      Name                      Writer     Likes  \
# 0      0                Let's Play  Leeanne M. Krecic (Mongie)     30.6M
# 1      1               True Beauty                     Yaongyi     39.9M
# 2      2       Midnight Poppy Land                    Lilydusk     10.4M
# 3      3               Age Matters                 Enjelicious     25.9M
# 4      4              Unholy Blood    Lina Im / Jeonghyeon Kim      9.9M
# ..   ...                       ...                         ...       ...
# 562  563                 Wolfsbane     Ryan Cady / Morgan Beem  1,44,341
# 563  564       Third Shift Society           Meredith Moriarty  8,66,428
# 564  565                Adamsville              Michael Regina  1,84,981
# 565  566               WEBTOON Now      LOZOLZ / Wyatt the Cat      1.9M
# 566  567  Staying Healthy Together             Various Artists      1.5M
#
#             Genre Rating Subscribers  \
# 0         Romance   9.62        4.2M
# 1         Romance    9.6        6.4M
# 2         Romance   9.81        2.1M
# 3         Romance   9.79        3.5M
# 4    Supernatural   9.85        1.5M
# ..            ...    ...         ...
# 562        Horror   9.68       66.3K
# 563  Supernatural   9.78      376.9K
# 564       Mystery   9.32       60.4K
# 565   Informative   9.25      459.2K
# 566   Informative   9.76      204.6K
#
#                                                Summary              Update  \
# 0    She's young, single and about to achieve her d...    UP EVERY TUESDAY
# 1    After binge-watching beauty videos online, a s...  UP EVERY WEDNESDAY
# 2    After making a grisly discovery in the country...   UP EVERY SATURDAY
# 3    She's a hopeless romantic who's turning 30's  ...  UP EVERY WEDNESDAY
# 4    When vampires destroy her chance to have the n...   UP EVERY THURSDAY
# ..                                                 ...                 ...
# 562  Following in her father's legacy, Quinn's enti...           COMPLETED
# 563  Life's funny. One minute you're jobless, deep ...     UP EVERY FRIDAY
# 564  "Adamsville" is an all ages series about two m...           COMPLETED
# 565                        Get your WEBTOON news here!     UP EVERY MONDAY
# 566  A series of tips for staying safe during the C...           COMPLETED
#
#                                           Reading Link Unnamed: 10
# 0    https://www.webtoons.com/en/romance/letsplay/l...         NaN
# 1    https://www.webtoons.com/en/romance/truebeauty...         NaN
# 2    https://www.webtoons.com/en/romance/midnight-p...         NaN
# 3    https://www.webtoons.com/en/romance/age-matter...         NaN
# 4    https://www.webtoons.com/en/supernatural/unhol...         NaN
# ..                                                 ...         ...
# 562  https://www.webtoons.com/en/horror/wolfsbane/l...         NaN
# 563  https://www.webtoons.com/en/supernatural/third...         NaN
# 564  https://www.webtoons.com/en/mystery/adamsville...         NaN
# 565  https://www.webtoons.com/en/tiptoon/webtoon-no...         NaN
# 566  https://www.webtoons.com/en/tiptoon/staying-he...         NaN
#
# [567 rows x 11 columns]

# %%
g = Graph()
g.parse('project ontology.owl', format='xml')
wto = Namespace('http://www.semanticweb.org/WebToons#')
g.bind('wto', wto)

# %%
name = dataframe['Name']
name_url = dataframe['Reading Link']
writer = dataframe['Writer']
likes = dataframe['Likes']
genre = dataframe['Genre']
rating = dataframe['Rating']
subscriber = dataframe['Subscribers']
summary = dataframe['Summary']
update = dataframe['Update']

# %%
for i in range(len(name_url)):
    if "https:" in name_url[i]:
        #adding the manhwa (the uri being used is informative)
        g.add((URIRef(name_url[i]),RDF.type,URIRef('http://dbpedia.org/resource/Manhwa')))
        g.add((URIRef(name_url[i]),RDFS.label,Literal(name[i], datatype=XSD.string)))
        
        #adding writers of the manhwa
        str_writer = str(writer[i])
        writers = str_writer.split("/")
        for w in writers:
            temp = str(w)
            temp = temp.replace(" ","_")
            temp = URIRef(wto+temp)
            g.add((URIRef(name_url[i]),URIRef('http://dbpedia.org/ontology/writer'),temp))
            g.add((temp,RDFS.label,Literal(str(w), datatype=XSD.string)))
          
        #Adding Total Likes
        l = likes[i]
        if type(l) == str:
            if l.find("M") != -1:
                n,m = l.split("M")
                numb = float(n)*1000000
                g.add((URIRef(name_url[i]),wto.TotalLikes,Literal(numb, datatype=XSD.double)))
            elif l.find("K") != -1:
                n,m = l.split("K")
                numb = float(n)*1000
                g.add((URIRef(name_url[i]),wto.TotalLikes,Literal(numb, datatype=XSD.double)))
        else:
            g.add((URIRef(name_url[i]),wto.TotalLikes,Literal(l, datatype=XSD.double)))
        
        #Adding genre of the webtoon
        g_temp = genre[i]
        g_temp = g_temp.replace(" ","_")
        g.add((URIRef(name_url[i]),URIRef('http://dbpedia.org/ontology/genre'),URIRef(wto+g_temp)))
        g.add((URIRef(wto+g_temp),RDFS.label,Literal(genre[i], datatype=XSD.string)))
        
        #Adding rating
        g.add((URIRef(name_url[i]),wto.rating,Literal(rating[i], datatype=XSD.double)))

        #Adding Total Subscribers
        s = subscriber[i]
        if type(s) == str:
            if s.find("M") != -1:
                n,m = s.split("M")
                numb = float(n)*1000000
                g.add((URIRef(name_url[i]),wto.subscribers,Literal(numb, datatype=XSD.double)))
            elif s.find("K") != -1:
                n,m = s.split("K")
                numb = float(n)*1000
                g.add((URIRef(name_url[i]),wto.subscribers,Literal(numb, datatype=XSD.double)))
        else:
            g.add((URIRef(name_url[i]),wto.subscribers,Literal(s, datatype=XSD.double)))
            
        #Adding webtoon summary/abstract
        g.add((URIRef(name_url[i]),URIRef("http://dbpedia.org/ontology/abstract"),Literal(summary[i], datatype=XSD.string)))
        
        #Weekly schedule
        g.add((URIRef(name_url[i]),wto.WeeklySchedule,Literal(update[i], datatype=XSD.string)))

print("Saving graph to 'webtoons.ttl':")
g.serialize(destination='webtoons.ttl', format='ttl')
# Out:
# Saving graph to 'webtoons.ttl':
# Saving graph to 'webtoons.ttl':
# <Graph identifier=N98393a993a9748709264133578bf3071 (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=N98393a993a9748709264133578bf3071 (<class 'rdflib.graph.Graph'>)>

# %%
def Query(g, string):
    result = g.query(string)
    for row in result:
        length = len(row)
        for i in range(length):
            if i == length-1:        
                print(row[i])
            else:
                print(row[i], end=', ')

# %%
g = Graph()
g.parse('webtoons.ttl', format='ttl')
# Out:
# <Graph identifier=Nf99cd513af074e4d9d83167b85378b9d (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=Nf99cd513af074e4d9d83167b85378b9d (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Get List of all Webtoons

# %%
def Query1(g):
    query="""Select Distinct ?name where{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name.
    }
    """
    Query(g, query)

Query1(g)
# Out:
# A Useless Villain
# Blood-Ink
# Brothers Bond
# Cape of Spirits
# Caster
# Code Adam
# Covenant
# Darbi
# Doom Breaker
# Dungeons & Artifacts
# Eleceed
# Girls of the Wild's
# GOSU
# Hardcore Leveling Warrior
# Hero Killer
# I Get Stronger the More I Eat
# Dr. Frost
# Infinite Leveling: Murim
# Jungle Juice
# LESSA 2 - The Crimson Knight
# LESSA
# Smity and Majesty
# The Spark in Your Eyes
# Noblesse: Rai's Adventure
# Noblesse
# Omniscient Reader
# 1000
# Ordeal
# Room of Swords
# Pound
# REAWAKENED MAN
# Return of the Blossoming Blade
# Return to Player
# microHUNTER
# TACIT
# Teenage Mercenary
# The Advanced Player ofthe Tutorial Tower
# The Eagle and the Snake
# The First Hunter
# The Gamer
# The God of High School
# The Princess's Jewels
# Random Chat
# Villain to Kill
# Date First, Love Later
# Warrior of the Wild
# Weak Hero
# 10th Dimension Boys
# 1111 Animals
# 3-Second Strip
# Adventures of God
# Andy Bass
# Aura from Another Planet
# AXED
# Moonlight Beauty Parlor
# Behind the GIFs
# Boyfriend of the Dead
# Brutally Honest
# BuzzFeed Comics
# Cursed Princess Club
# DON'T HATE
# dustinteractive
# Epic V
# Everywhere & Nowhere
# So You're Raising a Warrior
# CinnamonRoll
# God of Bath
# God, Please Make Me a Demon!
# HAPI BUNI
# Your Smile is a Trap
# Illustrated Internet
# Just Pancakes
# Library Ghost
# Live with Yourself!
# Love Advice from the Great Duke of Hell
# Mage & Demon Queen
# Meow Man
# Deadlove
# Locker & Opener
# MOONBEARD
# My Daughter is a Zombie
# My Dictator Boyfriend
# New Life Project
# Not So Shoujo Love Story
# Polidiocy
# RANDOMPHILIA
# Rooftops & Roommates
# Safely Endangered
# CARL
# Gul
# The DaneMen
# The Gentleman's Armchair
# The Sound of Your Heart
# Tickle Town
# Toaster Dude
# Meow Rangers
# Trailer Park Warlock
# Trash Bird
# Unlucky is as Lucky does
# The Wolf & Red Riding Hood
# Your Adventure
# A Man's Man
# About Death
# Acception
# Tales of Greed
# Aisopos
# All That You Are
# American Road Trip
# Annarasumanara
# Asterion
# Back to You
# All of Us Are Dead
# Unknown Caller
# Bastard
# Bite Me
# Chiller
# Ctrl+Z
# Dear X
# DEEP
# Delusion
# Epilogue
# Escape Room
# Fast Forward
# Forest of Humans
# Friday: Forbidden Tales
# Grasp
# HIVE
# Homesick
# It's Mine
# #Killstagram
# Live Forever
# Money Game
# My Deepest Secret
# Nightmare Factory
# Not Even Bones
# PIGPEN
# Rotten
# School Bus Graveyard
# See No Evil
# Shotgun Boy
# Shriek
# Sweet Home
# The Nuna at Our Office
# The Cliff
# The Savior's Time
# Cooking Comically
# Illuminated
# Staying Healthy Together
# WEBTOON Now
# naruto

# %% [markdown]
# Get List of all Writers

# %%
def Query2(g):
    query="""Select Distinct ?name where{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        <http://dbpedia.org/ontology/writer> ?o.
        # ?o rdfs:label ?name.
    }
    """
    Query(g, query)

Query2(g)
# Out:
# Yeoul
#  ODI
# Lupicut
# Kevin Grevioux
#  Ryan Benjamin
# Kris Nguyen
# Common
#  Noble Transmission
# Atterozen
# explodikid
# Sherard Jackson
# Blue-Deep
# Zerowater
#  UMKY
# Jeho Son
#  ZHENA
# HUN
# Giun Ryu
#  Mun Jeong Hoo
# Sehoon Kim
# Kkulbeol
#  Beolkkul
# Kitaeon
#  Frost Mourne
# Keon Tan
# Jinwoo Kim
#  Gonbung
# HYEONG EUN
#  JUDER
# POGO
# B.Y
#  JRobin
# Gisong
#  NemGa
#  Kwangsu Lee
#  UMI
# sing N song
# Chuck Brown
#  Sanford Greene
# Brent Bristol
# Tony Karnowski
#  Orlando Caicedo
# Yongtaek Chae
#  Jaehan Kim
# UMKY
#  SEHON
# NAGATERBANG
# KimDazzi
# YC
#  Rakyeon
# Bangguseok Gimssi
#  Omagam
# Angel Tovar
#  Chanwook Jeon
# dedart
# Sangyoung Seong
#  Sang-A
# Yongje Park
# Hyun hoo Joo
#  Kumtata
# Dongwoo Han
#  Dohee Lee
# Fupin
#  Eunji
# Taejun Pak
#  Kim Junghyun
# Jingle & DOXOâ™¥ï¸
#  Brian Koffler
# SEOPASS
#  RAZEN
# Cutbu
# 1111
# Bae Jin-Soo
# Teo
#  Corey
# KenneDuck
#  Gia
# Kyusam Kim
# Shren Patel
#  Emi MG
# Jimena Aranda
# AC Stuart
#  Kat Swenski
# Ushio
# Deya Muniz
# BuzzFeed Comics
# LambCat
# Pink_Alien
# Dustin Rogers
# Ardtron
#  GNICE
# Merryweather
#  PeaCH
# Hannah Patten
#  Violet Matter
# Meritxell Garcia
# Ilkwon Ha
# Bulsa
#  Yomgary
# Ryan Pagelow
# Momozerii
# Dami Lee
# HadeToons
# Mikey Heller
# Shen
#  David Mercier
# unfins
# Color_LES
# Olso
# AHNJOO
# James Squires
# Yun-chang Lee
#  Guy
# Cherng
# Curryuku
# Mahoney & Akel
#  Ryan Dunlavey
# Devin Bosco Le
# Zaanart
# Chris McCoy
# Nekucciola
# David Danemen
# Wes
# Cho Seok
#  soaporsalad
# littlebobler
# Matthew J. Rainwater
# Reza Farazmand
# Madeleine Rosca
# Sadaham
# Myung Hee
# Austen Marie
# Yoon Hyun-seung
#  Bang Seung-hyun
# Benjamin Fleuter
# Heylenne
# GMOW
# Meredith Moriarty
# Yunhui Na
# smbryms
# Lina Im
#  Jeonghyeon Kim
# SSO PARK
# Joo Dong-geun
# Carnby Kim
#  Youngchan Hwang
# AffectedMind
# MiTi
# VANZIUN
# TOWOO
#  Tae Heon Kim
# 10PARK
# PORTO
#  Junki Hong
# Junho Hwang
# Jeonghoon Hwang
# Ms. Freaky
# LuckS
# Ryoung
# Hanza Art
# R Schaeffer
#  Glamist
# Goodguy
# lilredbeany
# Gwangtanto
#  Maduru
#  Hongpil
# Juin Kim
#  Taejun Pak Webtoon Company
# Song Geukjang
# Tyler Capps
# Rachel Song
#  Maria Nguyen
# LOZOLZ
#  Wyatt the Cat
# Masahi Kishimoto

# %% [markdown]
# Get List of all Genres

# %%
def Query3(g):
    query="""Select Distinct ?genre where{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        <http://dbpedia.org/ontology/genre> ?o.
        # ?o rdfs:label ?genre.
    }
    """
    Query(g, query)

Query3(g)
# Out:
# Action
# Action
# Mystery
# Comedy
# Fantasy
# Sci-fi
# Drama
# Romance
# Slice of life
# Thriller
# Heartwarming
# Superhero
# Supernatural
# Historical
# Horror
# Sports
# Informative
# Adventure
# Action
# Action
# Mystery
# Comedy
# Fantasy
# Sci-fi
# Drama
# Romance
# Slice of life
# Thriller
# Heartwarming
# Superhero
# Supernatural
# Historical
# Horror
# Sports
# Informative
# Adventure

# %% [markdown]
# Get summary of Entered Manhwa

# %%
def Query4(g, data):
    query=f"""Select ?summary where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        <http://dbpedia.org/ontology/abstract> ?summary;
        Filter(?name = '{data}' ).
    }}
    """
    Query(g, query)

Query4(g,"Unholy Blood")
# Out:
# When vampires destroy her chance to have the normal life she's always wanted, Hayan is forced to draw on her darkest secret to rid the world of the merciless hunters that took it over 10 years ago. With the support of a rising star in the local police force, Hayan steps up to protect her loved ones, face her past, and get her revenge.
# When vampires destroy her chance to have the normal life she's always wanted, Hayan is forced to draw on her darkest secret to rid the world of the merciless hunters that took it over 10 years ago. With the support of a rising star in the local police force, Hayan steps up to protect her loved ones, face her past, and get her revenge.

# %% [markdown]
# Get Subscribers of Entered Manhwa

# %%
def Query5(g, data):
    query=f"""Select ?subs where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        wto:subscribers ?subs;
        Filter(?name = '{data}' ).
    }}
    """
    Query(g, query)

Query5(g,"Unholy Blood")
# Out:
# 1500000.0
# 1500000.0

# %% [markdown]
# Get Likes of Entered Manhwa

# %%
def Query6(g, data):
    query=f"""Select ?likes where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        wto:TotalLikes ?likes;
        Filter(?name = '{data}' ).
    }}
    """
    Query(g, query)

Query6(g,"Unholy Blood")
# Out:
# 9900000.0
# 9900000.0

# %% [markdown]
# Get Rating of Entered Manhwa

# %%
def Query7(g, data):
    query=f"""Select ?rating where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        wto:rating ?rating;
        Filter(?name = '{data}' ).
    }}
    """
    Query(g, query)

Query7(g,"Unholy Blood")
# Out:
# 9.85
# 9.85

# %% [markdown]
# Get Schedule of Entered Manhwa

# %%
def Query8(g, data):
    query=f"""Select ?schedule where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        wto:WeeklySchedule ?schedule;
        Filter(?name = '{data}' ).
    }}
    """
    Query(g, query)

Query8(g,"Unholy Blood")
# Out:
# UP EVERY THURSDAY
# UP EVERY THURSDAY

# %% [markdown]
# Get Reading Link of Entered Manhwa

# %%
def Query9(g, data):
    query=f"""Select ?s where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        Filter(?name = '{data}').
    }}
    """
    Query(g, query)

Query9(g,"Unholy Blood")
# Out:
# https://www.webtoons.com/en/supernatural/unholy-blood/list?title_no=1262
# https://www.webtoons.com/en/supernatural/unholy-blood/list?title_no=1262

# %% [markdown]
# Get list of Webtoons that are up every X day

# %%
def Query10(g, data):
    data= data.upper()
    query=f"""Select distinct ?name where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        wto:WeeklySchedule ?schedule;
        Filter(?schedule = '{data}' ).
    }}
    """
    Query(g, query)

Query10(g,"up every monday")
# Out:
# A Useless Villain
# Code Adam
# Dungeons & Artifacts
# Ordeal
# Room of Swords
# The Eagle and the Snake
# Cursed Princess Club
# Your Smile is a Trap
# Heir's Game
# Midnight Rain
# The Four of Them
# EMPYREA
# The Fabled Warrior
# Kubera
# Once a Hero
# Lovely Hell
# Raven Saga
# Spells From Hell
# The First Night With the Duke
# The Lazy Lord Masters the Sword
# How to Survive a Romance Fantasy
# Neon Revenge
# Tricked into Becoming the Heroine's Stepmother
# Tower of God
# Trump
# Everything is Fine
# Daily JoJo
# LoveBot
# Edith
# Let Me Stay Over Tonight!
# Marry Me!
# Nice To Meet You
# No Longer A Heroine!
# SubZero
# The Doctors are Out
# The Male Lead's Girl Friend
# To Love Your Enemy
# To You Who Swallowed a Star
# If AI Ruled the World
# Plum
# Kidults
# The Build Up
# Wind Breaker
# WEBTOON Now
# A Useless Villain
# Code Adam
# Dungeons & Artifacts
# Ordeal
# Room of Swords
# The Eagle and the Snake
# Cursed Princess Club
# Your Smile is a Trap
# Heir's Game
# Midnight Rain
# The Four of Them
# EMPYREA
# The Fabled Warrior
# Kubera
# Once a Hero
# Lovely Hell
# Raven Saga
# Spells From Hell
# The First Night With the Duke
# The Lazy Lord Masters the Sword
# How to Survive a Romance Fantasy
# Neon Revenge
# Tricked into Becoming the Heroine's Stepmother
# Tower of God
# Trump
# Everything is Fine
# Daily JoJo
# LoveBot
# Edith
# Let Me Stay Over Tonight!
# Marry Me!
# Nice To Meet You
# No Longer A Heroine!
# SubZero
# The Doctors are Out
# The Male Lead's Girl Friend
# To Love Your Enemy
# To You Who Swallowed a Star
# If AI Ruled the World
# Plum
# Kidults
# The Build Up
# Wind Breaker
# WEBTOON Now

# %% [markdown]
# What is the Genre of Entered Manhwa?

# %%
def Query11(g, data):
    query=f"""Select ?genre where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        <http://dbpedia.org/ontology/genre> ?o.
        # ?o rdfs:label ?genre.
        Filter(?name = '{data}').
    }}
    """
    Query(g, query)

Query11(g,"Unholy Blood")
# Out:
# Supernatural
# Supernatural

# %% [markdown]
# Get names of all Manhwas written by Entered Writer

# %%
def Query12(g, data):
    query=f"""Select distinct ?name where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        <http://dbpedia.org/ontology/writer> ?o.
        # ?o rdfs:label ?writer.
        Filter(?writer = '{data}' ).
    }}
    """
    Query(g, query)

Query12(g,"Paola Batalla")
# Out:
# Jackson's Diary
# Jackson's Diary

# %% [markdown]
# What Genre of Webtoon is most abundant?

# %%
def Query13(g):
    query="""
    SELECT ?g (COUNT(?genre) AS ?cnt)
    WHERE {
        # ?s <http://dbpedia.org/ontology/genre> ?genre.
        # ?genre rdfs:label ?g.

    }
    GROUP BY ?genre
    ORDER BY DESC(?cnt)
    limit 1

    """
    Query(g, query)

Query13(g)
# Out:
# Action, 94
# Action, 94

# %%
def Query14(g):
    query="""
    SELECT ?g (COUNT(?genre) AS ?cnt)
    WHERE {
        # ?s <http://dbpedia.org/ontology/genre> ?genre.
        # ?genre rdfs:label ?g.

    }
    GROUP BY ?genre
    ORDER BY DESC(?cnt)
    """
    Query(g, query)

Query14(g)
# Out:
# Action, 94
# Fantasy, 92
# Romance, 90
# Drama, 60
# Comedy, 51
# Slice of life, 48
# Thriller, 35
# Supernatural, 33
# Sci-fi, 30
# Superhero, 26
# Horror, 20
# Sports, 10
# Mystery, 9
# Historical, 4
# Informative, 4
# Heartwarming, 2
# Adventure, 1
# Action, 94
# Fantasy, 92
# Romance, 90
# Drama, 60
# Comedy, 51
# Slice of life, 48
# Thriller, 35
# Supernatural, 33
# Sci-fi, 30
# Superhero, 26
# Horror, 20
# Sports, 10
# Mystery, 9
# Historical, 4
# Informative, 4
# Heartwarming, 2
# Adventure, 1

# %% [markdown]
# What is the most liked Genre?

# %%
def Query15(g):
    query="""
    SELECT ?g (SUM(?likes) AS ?cnt)
    WHERE {
        # ?s <http://dbpedia.org/ontology/genre> ?genre;
        wto:TotalLikes ?likes.
        # ?genre rdfs:label ?g.

    }
    GROUP BY ?genre
    ORDER BY DESC(?cnt)
    limit 1
    """
    Query(g, query)

Query15(g)
# Out:
# Romance, 455000000.0
# Romance, 455000000.0

# %% [markdown]
# Ordered Total likes of all Genres?

# %%
def Query16(g):
    query="""
    SELECT ?g (SUM(?likes) AS ?cnt)
    WHERE {
        # ?s <http://dbpedia.org/ontology/genre> ?genre;
        wto:TotalLikes ?likes.
        # ?genre rdfs:label ?g.

    }
    GROUP BY ?genre
    ORDER BY DESC(?cnt)
    """
    Query(g, query)

Query16(g)
# Out:
# Romance, 455000000.0
# Action, 274820000.0
# Fantasy, 259300000.0
# Slice of life, 212300000.0
# Comedy, 197600000.0
# Drama, 172600000.0
# Supernatural, 68100000.0
# Thriller, 67900000.0
# Superhero, 50900000.0
# Sci-fi, 38900000.0
# Sports, 28800000.0
# Horror, 25900000.0
# Mystery, 11600000.0
# Informative, 3400000.0
# Heartwarming, 1500000.0
# Historical, 1100000.0
# Adventure, 10000.0
# Romance, 455000000.0
# Action, 274820000.0
# Fantasy, 259300000.0
# Slice of life, 212300000.0
# Comedy, 197600000.0
# Drama, 172600000.0
# Supernatural, 68100000.0
# Thriller, 67900000.0
# Superhero, 50900000.0
# Sci-fi, 38900000.0
# Sports, 28800000.0
# Horror, 25900000.0
# Mystery, 11600000.0
# Informative, 3400000.0
# Heartwarming, 1500000.0
# Historical, 1100000.0
# Adventure, 10000.0

# %% [markdown]
# Get main character of Entered Webtoon

# %%
def Query17(g, data):
    query=f"""Select ?maincharacter where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        wto:HasCharacter ?character.
        # ?character rdf:type <http://www.semanticweb.org/WebToons#Main_Character>;
        rdfs:label ?maincharacter.
        Filter(?name = '{data}' ).
    }}
    """
    Query(g, query)

Query17(g,"naruto")
# Out:
# naruto uzamaki
# naruto uzamaki

# %% [markdown]
# Get Side character of Entered Webtoon

# %%
def Query18(g, data):
    query=f"""Select ?maincharacter where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name;
        wto:HasCharacter ?character.
        # ?character rdf:type <http://www.semanticweb.org/WebToons#Side_Character>;
        rdfs:label ?maincharacter.
        Filter(?name = '{data}' ).
    }}
    """
    Query(g, query)

Query18(g,"naruto")
# Out:
# Sakura
# Sakura

# %% [markdown]
# In which chapter does Entered Character appear for the first time?

# %%
def Query19(g, data1, data2):
    query=f"""Select ?chapter where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name1;
        wto:HasCharacter ?character.
        # ?character rdfs:label ?name2.
        # ?character <http://www.semanticweb.org/WebToons#FirstAppearance> ?ch.
        # ?ch rdfs:label ?chapter.
        Filter(?name1 = '{data1}' && ?name2 ='{data2}').

    }}
    """
    Query(g, query)

Query19(g,"naruto", "naruto uzamaki")
# Out:
# naruto chapter 1
# naruto chapter 1

# %% [markdown]
# Get enemy of character X in Manhwa X

# %%
def Query20(g, data1, data2):
    query=f"""Select ?enemy where{{
        # ?s rdf:type <http://dbpedia.org/resource/Manhwa>;
        rdfs:label ?name1;
        wto:HasCharacter ?character.
        # ?character rdfs:label ?name2.
        # ?character <http://www.semanticweb.org/WebToons#Enemy> ?enm.
        # ?enm rdfs:label ?enemy.
        Filter(?name1 = '{data1}' && ?name2 ='{data2}').

    }}
    """
    Query(g, query)

Query20(g,"naruto", "sasuke uchiha")
# Out:
# naruto uzamaki
# naruto uzamaki
